# %% [markdown]
# # Final Capstone Project

# %% [markdown]
# ### Business problem description

# %% [markdown]
# During the worldwide corona crisis, it became clear that nightlife venues, restaurants and bars can be the sources of continued spread of the virus. Many countries are struggling to define clear concepts to protect their citizens. The aim of this analysis will be a generate a risk assessment for each neighborhood in the city of Munich.
#
# Based on the risk assessment one can concetrate efforts and enforce the rules where it is most necessary.

# %% [markdown]
# For this task I will leverage the Foursquare API and available puplic data for the city of Munich. I will cluster the neighborhoods based on the type, density and size of venues and create an overview map of high & low risk areas.

# %%
import pandas as pd
import folium
import bs4 as bs
import urllib.request
from geopy.geocoders import Nominatim 
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# ### Scrape city district data from Wikipedia, clean and translate columns

# %%
source = urllib.request.urlopen('https://de.wikipedia.org/wiki/Stadtbezirke_M%C3%BCnchens').read()
soup = bs.BeautifulSoup(source)

table = soup.find_all('table',{"class": "wikitable sortable"})
df = pd.read_html(str(table))[0]

# %%
df=df.drop(labels=["Nr.","Ausländer(%)"], axis=1)
df=df.drop(25)
df=df.rename(columns={"Stadtbezirk": "District", "Fläche(km²)": "Area(km²)", "Einwohner": "Inhabitants","Dichte(Einw./km²)":"Density(Inhab./km²)"})

# %% [markdown]
# ### Munich has 24 districts and a total of ca. 1.5m inhabitants

# %%
df
# Out:
#                                              District  Area(km²) Inhabitants  \
# 0                                      Altstadt-Lehel        315      21.100
# 1                        Ludwigsvorstadt-Isarvorstadt        440      51.644
# 2                                         Maxvorstadt        430      51.402
# 3                                      Schwabing-West        436      68.527
# 4                                       Au-Haidhausen        422      61.356
# 5                                            Sendling        394      40.983
# 6                                   Sendling-Westpark        781      59.643
# 7                                    Schwanthalerhöhe        207      29.743
# 8                               Neuhausen-Nymphenburg       1291      98.814
# 9                                             Moosach       1109      54.223
# 10                              Milbertshofen-Am Hart       1342      75.094
# 11                                 Schwabing-Freimann       2567      77.936
# 12                                        Bogenhausen       2371      87.950
# 13                                       Berg am Laim        631      46.098
# 14                                     Trudering-Riem       2245      73.206
# 15                                 Ramersdorf-Perlach       1990     116.327
# 16                            Obergiesing-Fasangarten        572      54.256
# 17                            Untergiesing-Harlaching        806      53.184
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...       1776      96.714
# 19                                             Hadern        922      49.898
# 20                                 Pasing-Obermenzing       1650      74.625
# 21                         Aubing-Lochhausen-Langwied       3406      47.813
# 22                                Allach-Untermenzing       1545      33.355
# 23                             Feldmoching-Hasenbergl       2894      61.774
# 24                                               Laim        529      56.546
#
#     Density(Inhab./km²)
# 0                 6.708
# 1                11.734
# 2                11.960
# 3                15.706
# 4                14.541
# 5                10.405
# 6                 7.632
# 7                14.367
# 8                 7.651
# 9                 4.888
# 10                5.597
# 11                3.036
# 12                3.709
# 13                7.300
# 14                3.261
# 15                5.847
# 16                9.485
# 17                6.601
# 18                5.445
# 19                5.410
# 20                4.523
# 21                1.404
# 22                2.159
# 23                2.135
# 24               10.698

# %%
from geopy.geocoders import Nominatim 

location_dic={}

for row in df.itertuples():
    address = row[1]+', Munich Germany'
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    location_dic[row[1]]=[latitude,longitude]    
df_loc = pd.DataFrame.from_dict(location_dic, orient='index', columns=["Latitude","Longitude"])
df_loc=df_loc.reset_index()
df_loc=df_loc.rename(columns={"index":"District"})

# %%
df_merged=df_loc.merge(df,on="District")

# %%
df_merged
# Out:
#                                              District   Latitude  Longitude  \
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 2                                         Maxvorstadt  48.151092  11.562418
# 3                                      Schwabing-West  48.164849  11.563500
# 4                                       Au-Haidhausen  48.128753  11.590536
# 5                                            Sendling  48.118012  11.539083
# 6                                   Sendling-Westpark  48.118031  11.519333
# 7                                    Schwanthalerhöhe  48.133782  11.541057
# 8                               Neuhausen-Nymphenburg  48.154222  11.531517
# 9                                             Moosach  48.179895  11.510571
# 10                              Milbertshofen-Am Hart  48.182385  11.575043
# 11                                 Schwabing-Freimann  48.170240  11.585389
# 12                                        Bogenhausen  48.154782  11.633484
# 13                                       Berg am Laim  48.123483  11.633451
# 14                                     Trudering-Riem  48.126036  11.663338
# 15                                 Ramersdorf-Perlach  48.114140  11.614255
# 16                            Obergiesing-Fasangarten  48.111156  11.588909
# 17                            Untergiesing-Harlaching  48.114963  11.570189
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...  48.102840  11.545979
# 19                                             Hadern  48.118064  11.481842
# 20                                 Pasing-Obermenzing  48.147785  11.460701
# 21                         Aubing-Lochhausen-Langwied  48.158437  11.414066
# 22                                Allach-Untermenzing  48.195994  11.457013
# 23                             Feldmoching-Hasenbergl  48.213804  11.541275
# 24                                               Laim  48.139551  11.502166
#
#     Area(km²) Inhabitants  Density(Inhab./km²)
# 0         315      21.100                6.708
# 1         440      51.644               11.734
# 2         430      51.402               11.960
# 3         436      68.527               15.706
# 4         422      61.356               14.541
# 5         394      40.983               10.405
# 6         781      59.643                7.632
# 7         207      29.743               14.367
# 8        1291      98.814                7.651
# 9        1109      54.223                4.888
# 10       1342      75.094                5.597
# 11       2567      77.936                3.036
# 12       2371      87.950                3.709
# 13        631      46.098                7.300
# 14       2245      73.206                3.261
# 15       1990     116.327                5.847
# 16        572      54.256                9.485
# 17        806      53.184                6.601
# 18       1776      96.714                5.445
# 19        922      49.898                5.410
# 20       1650      74.625                4.523
# 21       3406      47.813                1.404
# 22       1545      33.355                2.159
# 23       2894      61.774                2.135
# 24        529      56.546               10.698

# %%
CLIENT_ID = 'FQ2IDDRDQHPLRZPINBZP2U2NMNIRUV0RZ01Z4EPZKQGM13DM' # your Foursquare ID
CLIENT_SECRET = 'ZCMNXOPSI15W1OQ0WAKVOEREL0MYYJBY2PRBCVRUMHAQOYW3' # your Foursquare Secret

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FQ2IDDRDQHPLRZPINBZP2U2NMNIRUV0RZ01Z4EPZKQGM13DM
# CLIENT_SECRET:ZCMNXOPSI15W1OQ0WAKVOEREL0MYYJBY2PRBCVRUMHAQOYW3

# %%
search_query = '4d4b7105d754a06376d81259'
radius = 1000
VERSION = '20180604'
df_merged["Number_of_Bars"]=0
limit=200



for row in df_merged.itertuples():
    index = row[0]
    latitude = row[2]
    longitude = row[3]
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&limit={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, limit,radius)
    results = requests.get(url).json()
    venues = results['response']['venues']
    df_merged["Number_of_Bars"][index]=len(venues)
# Out:
# /Users/tobiasuthe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
df_merged
# Out:
#                                              District   Latitude  Longitude  \
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 2                                         Maxvorstadt  48.151092  11.562418
# 3                                      Schwabing-West  48.164849  11.563500
# 4                                       Au-Haidhausen  48.128753  11.590536
# 5                                            Sendling  48.118012  11.539083
# 6                                   Sendling-Westpark  48.118031  11.519333
# 7                                    Schwanthalerhöhe  48.133782  11.541057
# 8                               Neuhausen-Nymphenburg  48.154222  11.531517
# 9                                             Moosach  48.179895  11.510571
# 10                              Milbertshofen-Am Hart  48.182385  11.575043
# 11                                 Schwabing-Freimann  48.170240  11.585389
# 12                                        Bogenhausen  48.154782  11.633484
# 13                                       Berg am Laim  48.123483  11.633451
# 14                                     Trudering-Riem  48.126036  11.663338
# 15                                 Ramersdorf-Perlach  48.114140  11.614255
# 16                            Obergiesing-Fasangarten  48.111156  11.588909
# 17                            Untergiesing-Harlaching  48.114963  11.570189
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...  48.102840  11.545979
# 19                                             Hadern  48.118064  11.481842
# 20                                 Pasing-Obermenzing  48.147785  11.460701
# 21                         Aubing-Lochhausen-Langwied  48.158437  11.414066
# 22                                Allach-Untermenzing  48.195994  11.457013
# 23                             Feldmoching-Hasenbergl  48.213804  11.541275
# 24                                               Laim  48.139551  11.502166
#
#     Area(km²) Inhabitants  Density(Inhab./km²)  Number_of_Bars  \
# 0         315      21.100                6.708              50
# 1         440      51.644               11.734              50
# 2         430      51.402               11.960              48
# 3         436      68.527               15.706              48
# 4         422      61.356               14.541              49
# 5         394      40.983               10.405              47
# 6         781      59.643                7.632              19
# 7         207      29.743               14.367              46
# 8        1291      98.814                7.651              47
# 9        1109      54.223                4.888              23
# 10       1342      75.094                5.597              42
# 11       2567      77.936                3.036              49
# 12       2371      87.950                3.709              10
# 13        631      46.098                7.300              19
# 14       2245      73.206                3.261              12
# 15       1990     116.327                5.847              21
# 16        572      54.256                9.485              45
# 17        806      53.184                6.601              47
# 18       1776      96.714                5.445              29
# 19        922      49.898                5.410               7
# 20       1650      74.625                4.523              20
# 21       3406      47.813                1.404               4
# 22       1545      33.355                2.159               5
# 23       2894      61.774                2.135               5
# 24        529      56.546               10.698              38
#
#     Bar_Density_Index corona_risk marker_colors
# 0           15.555556        high        yellow
# 1           10.681818        high        yellow
# 2           11.395349        high        yellow
# 3            5.963303      medium         green
# 4           10.900474        high        yellow
# 5            5.837563      medium         green
# 6            0.640205         low          blue
# 7           22.705314   very high           red
# 8            1.936483         low          blue
# 9            0.991885         low          blue
# 10           0.968703         low          blue
# 11           0.545384         low          blue
# 12           0.084353         low          blue
# 13           0.792393         low          blue
# 14           0.178174         low          blue
# 15           0.150754         low          blue
# 16           1.923077         low          blue
# 17           3.722084      medium         green
# 18           0.450450         low          blue
# 19           0.325380         low          blue
# 20           0.909091         low          blue
# 21           0.029360         low          blue
# 22           0.194175         low          blue
# 23           0.000000         low          blue
# 24           2.079395         low          blue

# %%
df_merged["Bar_Density_Index"]=(df_merged["Number_of_Bars"]/df_merged["Area(km²)"])*100

# %%
df_merged
# Out:
#                                              District   Latitude  Longitude  \
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 2                                         Maxvorstadt  48.151092  11.562418
# 3                                      Schwabing-West  48.164849  11.563500
# 4                                       Au-Haidhausen  48.128753  11.590536
# 5                                            Sendling  48.118012  11.539083
# 6                                   Sendling-Westpark  48.118031  11.519333
# 7                                    Schwanthalerhöhe  48.133782  11.541057
# 8                               Neuhausen-Nymphenburg  48.154222  11.531517
# 9                                             Moosach  48.179895  11.510571
# 10                              Milbertshofen-Am Hart  48.182385  11.575043
# 11                                 Schwabing-Freimann  48.170240  11.585389
# 12                                        Bogenhausen  48.154782  11.633484
# 13                                       Berg am Laim  48.123483  11.633451
# 14                                     Trudering-Riem  48.126036  11.663338
# 15                                 Ramersdorf-Perlach  48.114140  11.614255
# 16                            Obergiesing-Fasangarten  48.111156  11.588909
# 17                            Untergiesing-Harlaching  48.114963  11.570189
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...  48.102840  11.545979
# 19                                             Hadern  48.118064  11.481842
# 20                                 Pasing-Obermenzing  48.147785  11.460701
# 21                         Aubing-Lochhausen-Langwied  48.158437  11.414066
# 22                                Allach-Untermenzing  48.195994  11.457013
# 23                             Feldmoching-Hasenbergl  48.213804  11.541275
# 24                                               Laim  48.139551  11.502166
#
#     Area(km²) Inhabitants  Density(Inhab./km²)  Number_of_Bars  \
# 0         315      21.100                6.708              50
# 1         440      51.644               11.734              50
# 2         430      51.402               11.960              48
# 3         436      68.527               15.706              48
# 4         422      61.356               14.541              49
# 5         394      40.983               10.405              47
# 6         781      59.643                7.632              19
# 7         207      29.743               14.367              46
# 8        1291      98.814                7.651              47
# 9        1109      54.223                4.888              23
# 10       1342      75.094                5.597              42
# 11       2567      77.936                3.036              49
# 12       2371      87.950                3.709              10
# 13        631      46.098                7.300              19
# 14       2245      73.206                3.261              12
# 15       1990     116.327                5.847              21
# 16        572      54.256                9.485              45
# 17        806      53.184                6.601              47
# 18       1776      96.714                5.445              29
# 19        922      49.898                5.410               7
# 20       1650      74.625                4.523              20
# 21       3406      47.813                1.404               4
# 22       1545      33.355                2.159               5
# 23       2894      61.774                2.135               5
# 24        529      56.546               10.698              38
#
#     Bar_Density_Index corona_risk marker_colors
# 0           15.873016        high        yellow
# 1           11.363636        high        yellow
# 2           11.162791        high        yellow
# 3           11.009174      medium         green
# 4           11.611374        high        yellow
# 5           11.928934      medium         green
# 6            2.432778         low          blue
# 7           22.222222   very high           red
# 8            3.640589         low          blue
# 9            2.073940         low          blue
# 10           3.129657         low          blue
# 11           1.908843         low          blue
# 12           0.421763         low          blue
# 13           3.011094         low          blue
# 14           0.534521         low          blue
# 15           1.055276         low          blue
# 16           7.867133         low          blue
# 17           5.831266      medium         green
# 18           1.632883         low          blue
# 19           0.759219         low          blue
# 20           1.212121         low          blue
# 21           0.117440         low          blue
# 22           0.323625         low          blue
# 23           0.172771         low          blue
# 24           7.183365         low          blue

# %%
df_merged['corona_risk'] = pd.cut(df_merged['Bar_Density_Index'], bins=4, 
                              labels=['low', 'medium', 'high', 'very high'])
df_merged['marker_colors'] = pd.cut(df_merged['Bar_Density_Index'], bins=4, 
                              labels=['blue', 'green', 'yellow', 'red'])

# %%
df_merged
# Out:
#                                              District   Latitude  Longitude  \
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 2                                         Maxvorstadt  48.151092  11.562418
# 3                                      Schwabing-West  48.164849  11.563500
# 4                                       Au-Haidhausen  48.128753  11.590536
# 5                                            Sendling  48.118012  11.539083
# 6                                   Sendling-Westpark  48.118031  11.519333
# 7                                    Schwanthalerhöhe  48.133782  11.541057
# 8                               Neuhausen-Nymphenburg  48.154222  11.531517
# 9                                             Moosach  48.179895  11.510571
# 10                              Milbertshofen-Am Hart  48.182385  11.575043
# 11                                 Schwabing-Freimann  48.170240  11.585389
# 12                                        Bogenhausen  48.154782  11.633484
# 13                                       Berg am Laim  48.123483  11.633451
# 14                                     Trudering-Riem  48.126036  11.663338
# 15                                 Ramersdorf-Perlach  48.114140  11.614255
# 16                            Obergiesing-Fasangarten  48.111156  11.588909
# 17                            Untergiesing-Harlaching  48.114963  11.570189
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...  48.102840  11.545979
# 19                                             Hadern  48.118064  11.481842
# 20                                 Pasing-Obermenzing  48.147785  11.460701
# 21                         Aubing-Lochhausen-Langwied  48.158437  11.414066
# 22                                Allach-Untermenzing  48.195994  11.457013
# 23                             Feldmoching-Hasenbergl  48.213804  11.541275
# 24                                               Laim  48.139551  11.502166
#
#     Area(km²) Inhabitants  Density(Inhab./km²)  Number_of_Bars  \
# 0         315      21.100                6.708              50
# 1         440      51.644               11.734              50
# 2         430      51.402               11.960              48
# 3         436      68.527               15.706              48
# 4         422      61.356               14.541              49
# 5         394      40.983               10.405              47
# 6         781      59.643                7.632              19
# 7         207      29.743               14.367              46
# 8        1291      98.814                7.651              47
# 9        1109      54.223                4.888              23
# 10       1342      75.094                5.597              42
# 11       2567      77.936                3.036              49
# 12       2371      87.950                3.709              10
# 13        631      46.098                7.300              19
# 14       2245      73.206                3.261              12
# 15       1990     116.327                5.847              21
# 16        572      54.256                9.485              45
# 17        806      53.184                6.601              47
# 18       1776      96.714                5.445              29
# 19        922      49.898                5.410               7
# 20       1650      74.625                4.523              20
# 21       3406      47.813                1.404               4
# 22       1545      33.355                2.159               5
# 23       2894      61.774                2.135               5
# 24        529      56.546               10.698              38
#
#     Bar_Density_Index corona_risk marker_colors
# 0           15.873016        high        yellow
# 1           11.363636        high        yellow
# 2           11.162791      medium         green
# 3           11.009174      medium         green
# 4           11.611374        high        yellow
# 5           11.928934        high        yellow
# 6            2.432778         low          blue
# 7           22.222222   very high           red
# 8            3.640589         low          blue
# 9            2.073940         low          blue
# 10           3.129657         low          blue
# 11           1.908843         low          blue
# 12           0.421763         low          blue
# 13           3.011094         low          blue
# 14           0.534521         low          blue
# 15           1.055276         low          blue
# 16           7.867133      medium         green
# 17           5.831266      medium         green
# 18           1.632883         low          blue
# 19           0.759219         low          blue
# 20           1.212121         low          blue
# 21           0.117440         low          blue
# 22           0.323625         low          blue
# 23           0.172771         low          blue
# 24           7.183365      medium         green

# %%
map_munich = folium.Map(location=[48.1, 11.5], zoom_start=10)
for lat, lng, district, corona_risk, marker_color in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['District'], df_merged['corona_risk'],df_merged["marker_colors"]):
    label = '{}, {}'.format(district, corona_risk)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=marker_color,
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_munich)  


map_munich
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
